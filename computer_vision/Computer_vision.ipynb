# %% [markdown]
# <h1>Определение возраста покупателей<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Введение" data-toc-modified-id="Введение-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Введение</a></span></li><li><span><a href="#Библиотеки" data-toc-modified-id="Библиотеки-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Библиотеки</a></span><ul class="toc-item"><li><span><a href="#Настройки" data-toc-modified-id="Настройки-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Настройки</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ:-до-прочтения-подсказки" data-toc-modified-id="Исследовательский-анализ:-до-прочтения-подсказки-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ: до прочтения подсказки</a></span><ul class="toc-item"><li><span><a href="#Labels" data-toc-modified-id="Labels-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Labels</a></span><ul class="toc-item"><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Проверка-на-пропуски" data-toc-modified-id="Проверка-на-пропуски-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Проверка на пропуски</a></span></li><li><span><a href="#Проверка-на-дубликаты" data-toc-modified-id="Проверка-на-дубликаты-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Проверка на дубликаты</a></span></li><li><span><a href="#Анализ" data-toc-modified-id="Анализ-3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>Анализ</a></span></li></ul></li><li><span><a href="#Фотографии" data-toc-modified-id="Фотографии-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Фотографии</a></span><ul class="toc-item"><li><span><a href="#Разрешение-фотографий" data-toc-modified-id="Разрешение-фотографий-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Разрешение фотографий</a></span></li><li><span><a href="#RGB" data-toc-modified-id="RGB-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>RGB</a></span></li><li><span><a href="#Несколько-фотографий" data-toc-modified-id="Несколько-фотографий-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Несколько фотографий</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Проверка-генератора-изображений-для-модели." data-toc-modified-id="Проверка-генератора-изображений-для-модели.-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Проверка генератора изображений для модели.</a></span></li><li><span><a href="#Обучение-модели" data-toc-modified-id="Обучение-модели-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Обучение модели</a></span><ul class="toc-item"><li><span><a href="#ResNet50" data-toc-modified-id="ResNet50-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>ResNet50</a></span></li><li><span><a href="#Разрешение-фотографий" data-toc-modified-id="Разрешение-фотографий-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Разрешение фотографий</a></span></li><li><span><a href="#Библиотеки-для-GPU-тренажёра" data-toc-modified-id="Библиотеки-для-GPU-тренажёра-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Библиотеки для GPU тренажёра</a></span></li><li><span><a href="#Функция-загрузки-тренировочной-выборки." data-toc-modified-id="Функция-загрузки-тренировочной-выборки.-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Функция загрузки тренировочной выборки.</a></span></li><li><span><a href="#Функция-загрузки-тестровой-выборки." data-toc-modified-id="Функция-загрузки-тестровой-выборки.-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Функция загрузки тестровой выборки.</a></span></li><li><span><a href="#Функция-создания-модели." data-toc-modified-id="Функция-создания-модели.-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Функция создания модели.</a></span></li><li><span><a href="#Функция-тренировки-модели." data-toc-modified-id="Функция-тренировки-модели.-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Функция тренировки модели.</a></span></li><li><span><a href="#Результат-вывода" data-toc-modified-id="Результат-вывода-5.8"><span class="toc-item-num">5.8&nbsp;&nbsp;</span>Результат вывода</a></span></li></ul></li><li><span><a href="#Анализ-обученной-модели" data-toc-modified-id="Анализ-обученной-модели-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Анализ обученной модели</a></span></li></ul></div>

# %% [markdown]
# ## Введение

# %% [markdown]
# Данные взяты с сайта ChaLearn Looking at People. Они находятся в папке
# /datasets/faces/.
# В нашем распоряжении одна папка со всеми изображениями (/final_files) и CSV-файл labels.csv с двумя колонками: `file_name` и `real_age`.
#
# База данных APPA-REAL содержит 7591 изображение.
#
# В оригинальном источнике изображения разделены на 4113 обучающих, 1500 действительных и 1978 тестовых изображений, представленных в папках train /, valid/ и test /.
#
# Наша задача сделать предсказатель возраста с погрешностью меньше 8 по MAE по фотографиям.

# %% [markdown]
# ## Библиотеки

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from tensorflow.keras.preprocessing.image import ImageDataGenerator

from PIL import Image

from IPython.display import display
import warnings
import os

# %% [markdown]
# ### Настройки

# %%
# для скрытия ошибок
warnings.filterwarnings("ignore")

# для увеличения окна вывода 
pd.options.display.max_rows = 300

# для задания размера графиков по умолчанию
plt.rcParams["figure.figsize"] = (7, 5)

# %% [markdown]
# ## Исследовательский анализ: до прочтения подсказки

# %% [markdown]
# Посмотрим, что находится в предоставленных нам каталогах.

# %%
os.listdir('/datasets/faces/')
# Out:
# ['labels.csv', 'final_files']

# %% [markdown]
# В первом каталоге лежит файла с метками/целевыми признаками и еще каталог. Посмотрим, что в нем.

# %%
os.listdir('/datasets/faces/final_files')
# Out:
# ['005226.jpg',
#  '007426.jpg',
#  '001184.jpg',
#  '007520.jpg',
#  '004415.jpg',
#  '001798.jpg',
#  '002797.jpg',
#  '004223.jpg',
#  '003420.jpg',
#  '003067.jpg',
#  '006282.jpg',
#  '002022.jpg',
#  '000578.jpg',
#  '003646.jpg',
#  '004896.jpg',
#  '003525.jpg',
#  '004968.jpg',
#  '002758.jpg',
#  '002428.jpg',
#  '002760.jpg',
#  '000274.jpg',
#  '003275.jpg',
#  '000633.jpg',
#  '000057.jpg',
#  '006168.jpg',
#  '001124.jpg',
#  '003623.jpg',
#  '007544.jpg',
#  '001073.jpg',
#  '004070.jpg',
#  '000457.jpg',
#  '004219.jpg',
#  '003596.jpg',
#  '002078.jpg',
#  '005171.jpg',
#  '003702.jpg',
#  '004917.jpg',
#  '000641.jpg',
#  '000646.jpg',
#  '005032.jpg',
#  '001362.jpg',
#  '004689.jpg',
#  '006338.jpg',
#  '006039.jpg',
#  '003202.jpg',
#  '007578.jpg',
#  '006236.jpg',
#  '007465.jpg',
#  '002291.jpg',
#  '002535.jpg',
#  '002492.jpg',
#  '002955.jpg',
#  '000686.jpg',
#  '006429.jpg',
#  '003990.jpg',
#  '001782.jpg',
#  '001454.jpg',
#  '002130.jpg',
# ...

# %% [markdown]
# А в нем много фотографий. Интересно сколько их?

# %%
len(os.listdir('/datasets/faces/final_files'))
# Out:
# 7591

# %% [markdown]
# Их 7591. Запомним это число.

# %% [markdown]
# ### Labels

# %% [markdown]
# #### Загрузка данных

# %% [markdown]
# Загрузим данны с метками о возрасте и укажим свои форматы.

# %%
data = pd.read_csv('/datasets/faces/labels.csv', dtype={'real_age': np.int8})
data.info()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7591 entries, 0 to 7590
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   file_name  7591 non-null   object
#  1   real_age   7591 non-null   int8
# dtypes: int8(1), object(1)
# memory usage: 66.8+ KB
#     file_name  real_age
# 0  000000.jpg         4
# 1  000001.jpg        18
# 2  000002.jpg        80
# 3  000003.jpg        50
# 4  000004.jpg        17

# %% [markdown]
# **Выводы**:
# - Загрузка прошла успешно.
# - Фотографии храняться в формате *.jpg* и пронумерованы.
# - Число записей о файлах соответствуе количеству файлов в каталоге с ними.

# %% [markdown]
# #### Проверка на пропуски

# %%
data.isna().count()
# Out:
# file_name    7591
# real_age     7591
# dtype: int64

# %% [markdown]
# **Вывод**: Пропусков нет.

# %% [markdown]
# #### Проверка на дубликаты

# %%
data.duplicated().sum()

# %% [markdown]
# **Вывод**: Дубликатов нет.

# %% [markdown]
# #### Анализ

# %% [markdown]
# Посмотрим статистику по возрастам.

# %%
data['real_age'].describe()
# Out:
# count    7591.000000
# mean       31.201159
# std        17.145060
# min         1.000000
# 25%        20.000000
# 50%        29.000000
# 75%        41.000000
# max       100.000000
# Name: real_age, dtype: float64

# %% [markdown]
# Построим график с усами.

# %%
sns.boxplot(data['real_age'])
plt.title('График с усами фотографий по возрасту')
plt.xlabel('Возраст')
plt.show()

# %% [markdown]
# Посмотрим на какие возраста приходится больше фотографий.

# %%
sns.kdeplot(data = data['real_age'], shade=True)
plt.title('График плотности фотографий по возрасту')
plt.xlabel('Возраст')
plt.ylabel('Количество фотографий такого возраста')
plt.show()

# %% [markdown]
# **Выводы**:
# - В нашей выборке 7591 значение. Дубликатов и пропусков нет,
# - Возраста представлены от 1 года до 100 лет,
# - Основное количество фотографий (третья квантиль) до 75 лет,
# - Средний возраст и медиана, и максимальное количество фотографий около 30 лет(29-31)

# %% [markdown]
# **Предположение**: В силу характера данных модель, скорее всего будет хорошо распознавать возраста в диапозоне от 10 лет до 60, возоможно 75 лет. Скорее всего это будет приемлимо для заказчика, так как этот диапозон и распределение интуитивно схожи с посетителями магазинов.

# %% [markdown]
# ### Фотографии

# %% [markdown]
# На примере нулевой фотографии проверим формат, разрешение.

# %% [markdown]
# #### Разрешение фотографий

# %%
zero_image = Image.open('/datasets/faces/final_files/000000.jpg')
array = np.array(zero_image)

display(array.shape)
plt.imshow(zero_image)
# Out:
# (114, 114, 3)

# %% [markdown]
# **Вывод**: У нас цветные фотографии расширения 114 на 144. Расширение *.jpg*.

# %% [markdown]
# #### RGB

# %% [markdown]
# Посмотрим какой канал у нас в 0 индексе.

# %%
red_channel = array[:, :, 0]

plt.imshow(red_channel)
plt.colorbar()

# %% [markdown]
# **Вывод**: Судя по характеру отображения цветов, 0 канал красный. Мы имеем дело с *RGB*.

# %% [markdown]
# #### Несколько фотографий

# %% [markdown]
# Возьмем из наших данных одинт батч/пакет из 16 фотографий и посмотрим на него. Будем использовать информацию, что мы получили из нулевой фотографии.

# %%
datagen = ImageDataGenerator(rescale=1/255) 

datagen_flow = datagen.flow_from_directory(
    # папка, в которой хранится датасет
    directory='/datasets/faces/',
    # к какому размеру приводить изображения
    target_size=(114, 114),
    # задаем, что у нас 3 канала rgb
    color_mode='rgb',
    # размер батча
    batch_size=16,
    # в каком виде выдавать метки классов
    class_mode=None,
    # фиксируем генератор случайных чисел (от англ. random seed)
    seed=54321) 

features= next(datagen_flow)

display(features.shape)
# Out:
# Found 7591 images belonging to 1 classes.
# (16, 114, 114, 3)

# %%
fig = plt.figure(figsize=(10,10))
for i in range(16):
    fig.add_subplot(4, 4, i+1)
    plt.imshow(features[i])
# для компактности удаляем оси и прижимаем изображения друг к другу
    plt.xticks([])
    plt.yticks([])
    plt.tight_layout()

# %% [markdown]
# **Вывод**: Наши данные состоят из изображений, которые содержит обрезанное и повернутое лицо с 40%-ным отступом это часть данных из нашего источника. Такие данные значительно облегчат работу, так как лицо будет основным источником информации о возрасте.

# %% [markdown]
# ### Выводы

# %% [markdown]
# 0. Наши данны хорошего качества: дубликатов и пропусков нет, проведена предобработка: лицо видно и занимает значимую часть площади. Разрешение фотографий близко к оптимальному для аппаратных мощьностей и качеству изображения.
# 1. Мы будем решать задачу регрессии: определение возраста.
# 2. Так как мы будем работать с изображениями, то мы будем использовать нейронные сети.
# 3. Размеры фотографий 114 на 114 на 3 - достаточно крупные, поэтому мы будем использовать в основном свёрточные слои и только в конце полносвязные. Замечатьельно будет, если мы сможем использовать части предобученных нейронных сетей, например, с архитектурой ResNet50.
# 4. Последний слой будет с одним нейроном( нам нужно только одно значение возраста). Функция активации у него будет ReLu(отрицательные значения возраста нам не нужны)
# 5. Заказчик выбрал метрику MAE, но это не мешает нам использовать для обучения  функцией потерь MSE(возможно взять производную- это много стоит).

# %% [markdown]
# ## Проверка генератора изображений для модели.

# %% [markdown]
# Для того, чтобы наши фотографии имели целевой признак при подаче данных модели используем *flow_from_dataframe*. Чтобы проверить его работу посмотрим на фотографии и метки/целевые признаки из первого батча/пакета.

# %%
labels = pd.read_csv('/datasets/faces/labels.csv')
train_datagen = ImageDataGenerator(rescale=1./255)
train_gen_flow = train_datagen.flow_from_dataframe(
        dataframe=labels,
        directory='/datasets/faces/final_files/',
        x_col='file_name',
        y_col='real_age',
        target_size=(114, 114),
        batch_size=16,
        class_mode='raw',
        seed=12345)
# Out:
# Found 7591 validated image filenames.

# %%
# график плотности изображений по годам.
# sns.kdeplot(data = labels['real_age'], shade=True)
# plt.title('График плотности фотографий по возрасту')
# plt.xlabel('Возраст')
# plt.ylabel('Количество фотографий такого возраста')
# plt.show()

# %% [markdown]
# Вытащим батч из потока. Проверим размерности.

# %%
image, label = train_gen_flow.next()
image.shape, label.shape
# Out:
# ((16, 114, 114, 3), (16,))

# %% [markdown]
# Посмотрим на изображения.

# %%
fig_1 = plt.figure(figsize=(10,10))
for i in range(16):
    fig_1.add_subplot(4, 4, i+1)
    image
    plt.imshow(image[i])
# для компактности удаляем оси и прижимаем изображения друг к другу
    plt.xticks([])
    plt.yticks([])
    plt.tight_layout()

# %% [markdown]
# Посмотрим на метки.

# %%
label
# Out:
# array([50, 41, 46, 85, 14, 40, 14, 53,  4, 32, 14, 23, 37, 62, 21, 58])

# %% [markdown]
# **Вывод**: Данные для модели будут подаваться корректно.

# %% [markdown]
# ## Обучение модели

# %% [markdown]
# Код в этом разделе запускается в отдельном GPU-тренажёре, поэтому оформлен не как ячейка с кодом, а как код в текстовой ячейке.
#
# Мы отдельно вынесем библиотеки для GPU-тренажёра.

# %% [markdown]
# Как мы сделали выводы выше на основе полученных данных:
# - функция потерь MSE,
# - метрика MAE,
# - основой модели будет предобученная нейронная сеть с архитектурой ResNet.

# %% [markdown]
# ### ResNet50

# %% [markdown]
# В модели мы будем использовать предобученную нейронную сеть ResNet50. Для нас это значительно сократит время обучение модели и повысит качество обучения. Мы изменим лишь последние слои, чтобы решить нашу задачу регрессии.

# %% [markdown]
# ### Разрешение фотографий

# %% [markdown]
# Наши фотографии имеют разрешение 114 на 114, но мы будем использовать часть предобученной нейронной сети *ResNet50*, которая обучалась на фотографиях разрешением 224 на 224. Поэтому мы будем подавать модели наши фотографии в разрешении 224 на 224.

# %% [markdown]
# ### Библиотеки для GPU тренажёра

# %% [markdown]
# ```
# import pandas as pd
#
# from tensorflow.keras import Sequential
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.applications.resnet import ResNet50
# from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Flatten, Dropout
#
# from tensorflow.keras.optimizers import Adam
# ```

# %% [markdown]
# ### Функция загрузки тренировочной выборки.

# %% [markdown]
# ```
# def load_train(path):
#     labels = pd.read_csv(path+'labels.csv')
#     train_datagen = ImageDataGenerator(rescale=1/255
#                                        , validation_split=0.25
#                                        , horizontal_flip=True
#                                       )
#
#
#     train_datagen_flow = train_datagen.flow_from_dataframe(dataframe=labels
#                                                        , directory=path + '/final_files'
#                                                        , x_col='file_name'
#                                                        , y_col='real_age'
#                                                        , target_size=(224, 224)
#                                                        , batch_size=16
#                                                        , class_mode='raw'
#                                                        , seed=12345
#                                                        , subset='training'
#                                                       )
#
#     return train_datagen_flow
# ```

# %% [markdown]
# ### Функция загрузки тестровой выборки.

# %% [markdown]
# ```
# def load_test(path):
#     labels = pd.read_csv(path+'labels.csv')
#     test_datagen = ImageDataGenerator(rescale=1/255
#                                        , validation_split=0.25
#                                       )
#
#
#     test_datagen_flow = test_datagen.flow_from_dataframe(dataframe=labels
#                                                        , directory=path + '/final_files'
#                                                        , x_col='file_name'
#                                                        , y_col='real_age'
#                                                        , target_size=(224, 224)
#                                                        , batch_size=16
#                                                        , class_mode='raw'
#                                                        , seed=12345
#                                                        , subset='validation'
#                                                       )
#
#     return test_datagen_flow
# ```

# %% [markdown]
# ### Функция создания модели.

# %% [markdown]
# ```
# def create_model(input_shape):
#     backbone = ResNet50(input_shape=input_shape
#                         , weights=
#                         '/datasets/keras_models/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5'
#                         , include_top=False)
#
#     model = Sequential()
#     model.add(backbone)
#     model.add(GlobalAveragePooling2D())
#     model.add(Dense(100, activation='relu'))
#     model.add(Dense(1, activation='relu'))
#
#     optimizer = Adam(
#         lr=0.0005
#     )
#     model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mean_absolute_error'])
#     return model
# ```

# %% [markdown]
# ### Функция тренировки модели.

# %% [markdown]
# ```
# def train_model(model, train_data, test_data, batch_size=None, epochs=30,
#                 steps_per_epoch=None, validation_steps=None):
#
#     if steps_per_epoch is None:
#         steps_per_epoch = len(train_data)
#     if validation_steps is None:
#         validation_steps = len(test_data)
#
#     model.fit(train_data,
#               validation_data=test_data,
#               batch_size=batch_size, epochs=epochs,
#               steps_per_epoch=steps_per_epoch,
#               validation_steps=validation_steps,
#               verbose=2)
#
#     return model
# ```

# %% [markdown]
# ### Результат вывода

# %% [markdown]
# ```
# 2023-07-24 16:29:19.104239: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer.so.6
# 2023-07-24 16:29:19.106661: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer_plugin.so.6
# 2023-07-24 16:29:20.048158: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2023-07-24 16:29:20.058232: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:8b:00.0 name: Tesla V100-SXM2-32GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2023-07-24 16:29:20.058317: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2023-07-24 16:29:20.058352: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2023-07-24 16:29:20.060892: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2023-07-24 16:29:20.061407: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2023-07-24 16:29:20.064259: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2023-07-24 16:29:20.065627: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2023-07-24 16:29:20.065704: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-07-24 16:29:20.069475: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# Using TensorFlow backend.
# Found 5694 validated image filenames.
# Found 1897 validated image filenames.
# 2023-07-24 16:29:20.250463: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-07-24 16:29:20.257134: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-07-24 16:29:20.257834: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x43e96d0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-07-24 16:29:20.257866: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-07-24 16:29:20.450066: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x42c5dd0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-07-24 16:29:20.450120: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla V100-SXM2-32GB, Compute Capability 7.0
# 2023-07-24 16:29:20.452636: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:8b:00.0 name: Tesla V100-SXM2-32GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2023-07-24 16:29:20.452714: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2023-07-24 16:29:20.452728: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2023-07-24 16:29:20.452766: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2023-07-24 16:29:20.452780: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2023-07-24 16:29:20.452793: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2023-07-24 16:29:20.452805: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2023-07-24 16:29:20.452816: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-07-24 16:29:20.457213: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# 2023-07-24 16:29:20.457326: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2023-07-24 16:29:21.007824: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1096] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-07-24 16:29:21.007886: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102]      0
# 2023-07-24 16:29:21.007897: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] 0:   N
# 2023-07-24 16:29:21.011730: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-07-24 16:29:21.011794: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1241] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10240 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:8b:00.0, compute capability: 7.0)
# <class 'tensorflow.python.keras.engine.sequential.Sequential'>
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 356 steps, validate for 119 steps
# Epoch 1/30
# 2023-07-24 16:29:33.429134: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2023-07-24 16:29:33.769955: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 356/356 - 70s - loss: 217.1627 - mean_absolute_error: 11.2778 - val_loss: 291.4846 - val_mean_absolute_error: 12.8105
# Epoch 2/30
# 356/356 - 56s - loss: 136.2844 - mean_absolute_error: 8.9837 - val_loss: 291.8163 - val_mean_absolute_error: 13.8641
# Epoch 3/30
# 356/356 - 56s - loss: 113.2675 - mean_absolute_error: 8.1345 - val_loss: 197.0386 - val_mean_absolute_error: 11.0082
# Epoch 4/30
# 356/356 - 56s - loss: 95.5756 - mean_absolute_error: 7.4990 - val_loss: 183.3303 - val_mean_absolute_error: 10.0573
# Epoch 5/30
# 356/356 - 55s - loss: 77.3147 - mean_absolute_error: 6.7052 - val_loss: 244.2534 - val_mean_absolute_error: 11.3074
# Epoch 6/30
# 356/356 - 56s - loss: 62.9204 - mean_absolute_error: 6.0983 - val_loss: 133.6181 - val_mean_absolute_error: 8.6020
# Epoch 7/30
# 356/356 - 58s - loss: 53.4470 - mean_absolute_error: 5.6076 - val_loss: 138.9295 - val_mean_absolute_error: 9.2621
# Epoch 8/30
# 356/356 - 58s - loss: 50.5569 - mean_absolute_error: 5.4649 - val_loss: 123.8833 - val_mean_absolute_error: 8.2876
# Epoch 9/30
# 356/356 - 57s - loss: 41.4072 - mean_absolute_error: 4.9214 - val_loss: 90.2617 - val_mean_absolute_error: 7.2160
# Epoch 10/30
# 356/356 - 55s - loss: 34.1284 - mean_absolute_error: 4.4487 - val_loss: 124.4515 - val_mean_absolute_error: 8.1231
# Epoch 11/30
# 356/356 - 55s - loss: 30.3405 - mean_absolute_error: 4.2368 - val_loss: 126.6205 - val_mean_absolute_error: 8.4810
# Epoch 12/30
# 356/356 - 56s - loss: 26.9853 - mean_absolute_error: 3.9769 - val_loss: 94.1831 - val_mean_absolute_error: 7.2266
# Epoch 13/30
# 356/356 - 57s - loss: 22.6657 - mean_absolute_error: 3.6401 - val_loss: 89.8582 - val_mean_absolute_error: 7.0745
# Epoch 14/30
# 356/356 - 56s - loss: 26.7168 - mean_absolute_error: 3.9351 - val_loss: 84.5191 - val_mean_absolute_error: 6.9978
# Epoch 15/30
# 356/356 - 58s - loss: 25.8222 - mean_absolute_error: 3.9221 - val_loss: 95.1900 - val_mean_absolute_error: 7.4900
# Epoch 16/30
# 356/356 - 58s - loss: 21.8368 - mean_absolute_error: 3.5929 - val_loss: 82.2035 - val_mean_absolute_error: 6.7795
# Epoch 17/30
# 356/356 - 57s - loss: 19.6959 - mean_absolute_error: 3.4012 - val_loss: 90.8398 - val_mean_absolute_error: 7.1352
# Epoch 18/30
# 356/356 - 55s - loss: 17.9573 - mean_absolute_error: 3.2255 - val_loss: 91.2913 - val_mean_absolute_error: 7.0104
# Epoch 19/30
# 356/356 - 55s - loss: 15.9746 - mean_absolute_error: 3.0707 - val_loss: 78.4118 - val_mean_absolute_error: 6.5357
# Epoch 20/30
# 356/356 - 57s - loss: 15.6972 - mean_absolute_error: 3.0480 - val_loss: 81.7598 - val_mean_absolute_error: 6.6940
# Epoch 21/30
# 356/356 - 56s - loss: 15.7739 - mean_absolute_error: 3.0350 - val_loss: 85.4035 - val_mean_absolute_error: 6.7876
# Epoch 22/30
# 356/356 - 55s - loss: 15.5268 - mean_absolute_error: 3.0541 - val_loss: 84.2381 - val_mean_absolute_error: 6.9947
# Epoch 23/30
# 356/356 - 56s - loss: 17.0687 - mean_absolute_error: 3.1452 - val_loss: 118.0951 - val_mean_absolute_error: 8.0182
# Epoch 24/30
# 356/356 - 57s - loss: 16.6730 - mean_absolute_error: 3.1265 - val_loss: 78.6613 - val_mean_absolute_error: 6.6706
# Epoch 25/30
# 356/356 - 59s - loss: 14.5658 - mean_absolute_error: 2.9236 - val_loss: 83.2808 - val_mean_absolute_error: 7.0050
# Epoch 26/30
# 356/356 - 56s - loss: 13.2129 - mean_absolute_error: 2.8083 - val_loss: 77.2394 - val_mean_absolute_error: 6.5588
# Epoch 27/30
# 356/356 - 56s - loss: 12.6165 - mean_absolute_error: 2.6947 - val_loss: 77.3439 - val_mean_absolute_error: 6.5945
# Epoch 28/30
# 356/356 - 56s - loss: 11.4117 - mean_absolute_error: 2.5658 - val_loss: 74.8221 - val_mean_absolute_error: 6.4656
# Epoch 29/30
# 356/356 - 56s - loss: 11.0730 - mean_absolute_error: 2.5212 - val_loss: 82.1312 - val_mean_absolute_error: 6.8108
# Epoch 30/30
# 356/356 - 56s - loss: 10.1817 - mean_absolute_error: 2.4352 - val_loss: 81.4259 - val_mean_absolute_error: 6.6228
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 119/119 - 11s - loss: 81.4259 - mean_absolute_error: 6.6228
# Test MAE: 6.6228
# ```

# %% [markdown]
# ## Анализ обученной модели

# %% [markdown]
# Наша модель выполнила поставленную задачу: пограшность по MAE меньше 8. Мы добились результата даже меньше 7.
#
# Мы использовали предобученную нейронную сеть ResNet50 как основу. На последних слоях использовали полносвязные слои со 100 нейронам и 1 нейроном.
#
# Функция активации была ReLu она не позволяла градиенту затухать и убирала отрицательные значения (возраст у нас только положительный).
#
# Метрика MAE, но функция потерь MSE.
#
# Оптимизатор Adam(lr=0.0005).
#
# Для увеличения выборки мы использовали только горизонтальный флип (задумывались и о вертикальном, но цели были достигнуты ранее). Этого было достаточно, так как наши фотографии были предварительно хорошо и одинаково предобработаны.
#
# Мы использовали 30 эпох, по которым прошли батчами по 16 объектов.
#
# На обучающей выборке значения MAE и MSE уменьшались все 30 эпох. А вот на тестовой выборке в 25% после 14 эпохи мы наблюдали и рост и падение показателей. На 23 эпохе мы получили значение MAE даже выше 8. Но в основном, после 11 эпохи на тестовой выборке задача была решена, и мы получали новые минимумы.
#
# При более чем 50 слоях трудно говорить о переобученности, вероятно, с определенного этапа мы попадаем в коридор значений и можно продолжать наблюдения за обученим, пока нижняя граница этого коридора продолжает падать. Но это мы проверим позже :)
#
# А на данном этапе мы получили модель, которая решает поставленную задачу.
